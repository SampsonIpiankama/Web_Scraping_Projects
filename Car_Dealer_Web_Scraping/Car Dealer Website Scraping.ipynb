# %% [markdown]
# # Import Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

# %% [markdown]
# # HTTP Request

# %% [markdown]
# #### Store website in a variable

# %%
website = "https://cars45.com/listing?region_subdomain=abuja"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"
}

# %% [markdown]
# #### Get Request

# %%
r = requests.get(website, headers = headers)

# %% [markdown]
# #### Response Status Code

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# Since our status_code for r is 200, then all is well

# %% [markdown]
# # Making the Soup Object

# %%
#This will give me access to the HTML elements of the website and represent it as a nested data structure
#I'm using the "lxml parser because it is faster than the html.

soup=BeautifulSoup(r.content,"lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://assets.jiji.ng/static/bundles/css/vue-cars-js.00a4b26d13358d289af5.min.css" rel="stylesheet" type="text/css"/>
#   <link href="https://assets.jiji.ng/static/cars45_files/favicon.ico" rel="icon"/>
#   <meta content="#58B4AC" name="theme-color"/>
#   <title>
#    Used Cars For Sale In Nigeria âœ“ Price On Cars45.Com
#   </title>
#   <meta content="Cars45 âœ“ find the best car ðŸš— for sale in nigeria âœ“ prices from â‚¦ 1,800,000 on cars45.com" name="description"/>
#   <meta content="noindex,follow" name="robots"/>
#  </head>
#  <body>
#   <div class="js-gulp-svg-bundle">
#   </div>
#   <script nonce="FHDnU4adUXYeacirGGkVHl6K1bOozYMZ">
#    (function (svgBundleName, svgAjaxUrl) {
#             var storageSvgHash = localStorage ? localStorage.getItem("JijiUserSvgHashBundleName") : null;
#             var storageSvgBundle = localStorage ? localStorage.getItem("JijiUserSvgBundle") : null;
#             if (localStorage && storageSvgHash && storageSvgBundle && storageSvgHash === svgBundleName) {
#                 document.querySelector('.js-gulp-svg-bundle').innerHTML = storageSvgBundle
#             } else {
#                 var newXHR = new XMLHttpRequest();
#                 newXHR.onreadystatechange = function() {
#                     if(newXHR.readyState === 4) {
#                         if(newXHR.status === 200) {
#                             if (localStorage) {
#                                 localStorage.setItem('JijiUserSvgHashBundleName', svgBundleName);
#                                 localStorage.setItem('JijiUserSvgBundle', newXHR.responseText);
#                             }
#                             document.querySelector('.js-gulp-svg-bundle').innerHTML = newXHR.responseText
#                         }
#                     }
#                 };
#                 newXHR.open('GET', svgAjaxUrl);
#                 newXHR.send();
#             }
#          }('sprite-svg-6c37d002.svg', 'https://assets.jiji.ng/static/bundles/sprites/svg/sprite-svg-6c37d002.svg'));
#   </script>
#   <header>
#    <div class="main-container">
#     <div class="nav-flex flex justify-between align-center">
#      <div class="nav-form flex">
#       <a class="nav-form__logo-link flex align-center" href="/">
#        <img alt="Cars45 logo" src="https://assets.jiji.ng/static/cars45_files/cars45_logo.svg"/>
#       </a>
#       <form action="/listing" class="" method="get">
#        <label name="">
#         <button>
#          <img alt="Search" src="https://assets.jiji.ng/static/cars45_files/search.svg"/>
#         </button>
#         <input id="search_web" name="query" placeholder="Find car by model, year..." type="search"/>
#        </label>
#       </form>
#      </div>
#      <a class="nav-flex__sell-car" href='javascript: document.location.href = "/new";' rel="nofollow">
#       SELL
#       <span>
#        MY CAR
#       </span>
#      </a>
#     </div>
#    </div>
#   </header>
#   <section class="main-container">
#    <div class="b-cars-short-filters-mobile-only" id="js-vue-cars-scope-short-filters">
#     <fixed-background>
#     </fixed-background>
#     <portal-target class="qa-portal-popup" name="popup">
#     </portal-target>
#     <portal-target class="qa-portal-popup-mobile-select" name="popup-mobile-select">
#     </portal-target>
#     <short-filters :filters='{"scheme": [{"attr_id": 1000000, "attr_name": "Inspection", "attr_parent_id": null, "attr_parent_name": null, "attr_type": "str", "filter_name": "filter_inspection", "filter_placeholder": null, "filter_type": "term", "for_header": true, "is_multiple": false, "label": "Inspection", "parent_slug": null, "popular_values": [], "possible_values": [{"count": 166, "value": "Inspected"}, {"count": 9592, "value": "Not inspected"}], "slug": "filter_inspection", "value": null, "visual_type": "select"}, {"attr_id": 1, "attr_name": "Make", "attr_parent_id": null, "attr_parent_name": null, "attr_type": "str", "filter_name": "filter_attr_1_make", "filter_placeholder": null, "filter_type": "term", "for_header": true, "is_multiple": false, "label": "Make", "parent_slug": null, "popular_values": [{"count": 259, "value": "Ford"}, {"count": 847, "value": "Honda"}, {"count": 941, "value": "Lexus"}, {"count": 1774, "value": "Mercedes-Benz"}, {"count": 3988, "value": "Toyota"}], "possible_values": [{"count": 84, "value": "Acura"}, {"count": 2, "value": "Alfa Romeo"}, {"count": 0, "value": "Aston Martin"}, {"count": 31, "value": "Audi"}, {"count": 0, "value": "BAW"}, {"count": 9, "value": "Bentley"}, {"count": 231, "value": "BMW"}, {"count": 2, "value": "Brabus"}, {"count": 4, "value": "Buick"}, {"count": 21, "value": "Cadillac"}, {"count": 1, "value": "Changan"}, {"count": 0, "value": "Chery"}, {"count": 52, "value": "Chevrolet"}, {"count": 24, "value": "Chrysler"}, {"count": 1, "value": "Citroen"}, {"count": 0, "value": "Daewoo"}, {"count": 0, "value": "Daihatsu"}, {"count": 0, "value": "Datsun"}, {"count": 39, "value": "Dodge"}, {"count": 0, "value": "Dongfeng"}, {"count": 3, "value": "Ferrari"}, {"count": 2, "value": "Fiat"}, {"count": 259, "value": "Ford"}, {"count": 0, "value": "Foton"}, {"count": 2, "value": "GAC"}, {"count": 0, "value": "Geely"}, {"count": 11, "value": "GMC"}, {"count": 0, "value": "Great Wall"}, {"count": 847, "value": "Honda"}, {"count": 0, "value": "Hummer"}, {"count": 244, "value": "Hyundai"}, {"count": 23, "value": "Infiniti"}, {"count": 0, "value": "Isuzu"}, {"count": 5, "value": "IVM"}, {"count": 2, "value": "JAC"}, {"count": 26, "value": "Jaguar"}, {"count": 31, "value": "Jeep"}, {"count": 0, "value": "Joylong"}, {"count": 132, "value": "Kia"}, {"count": 11, "value": "Lamborghini"}, {"count": 248, "value": "Land Rover"}, {"count": 941, "value": "Lexus"}, {"count": 9, "value": "Lincoln"}, {"count": 0, "value": "Mahindra"}, {"count": 4, "value": "Maserati"}, {"count": 63, "value": "Mazda"}, {"count": 1774, "value": "Mercedes-Benz"}, {"count": 1, "value": "Mercury"}, {"count": 2, "value": "MG"}, {"count": 34, "value": "Mini"}, {"count": 16, "value": "Mitsubishi"}, {"count": 0, "value": "Morris"}, {"count": 103, "value": "Nissan"}, {"count": 0, "value": "Nord"}, {"count": 8, "value": "Opel"}, {"count": 230, "value": "Peugeot"}, {"count": 0, "value": "Polaris"}, {"count": 82, "value": "Pontiac"}, {"count": 11, "value": "Porsche"}, {"count": 1, "value": "Renault"}, {"count": 12, "value": "Rolls-Royce"}, {"count": 5, "value": "Rover"}, {"count": 1, "value": "Saab"}, {"count": 3, "value": "Saturn"}, {"count": 7, "value": "Scion"}, {"count": 0, "value": "Seat"}, {"count": 2, "value": "Skoda"}, {"count": 0, "value": "Smart"}, {"count": 0, "value": "SsangYong"}, {"count": 6, "value": "Subaru"}, {"count": 4, "value": "Suzuki"}, {"count": 0, "value": "Tata"}, {"count": 3988, "value": "Toyota"}, {"count": 89, "value": "Volkswagen"}, {"count": 11, "value": "Volvo"}, {"count": 4, "value": "Other Make"}], "slug": "filter_attr_1_make", "value": null, "visual_type": "select"}, {"attr_id": 119, "attr_name": "Year of manufacture", "attr_parent_id": null, "attr_parent_name": null, "attr_type": "int", "filter_data": {"max": {"default": 2022.0, "fieldname": "filter_attr_119_year_of_manufacture__max", "value": ""}, "min": {"default": 1965.0, "fieldname": "filter_attr_119_year_of_manufacture__min", "value": ""}}, " ...
#     </short-filters>
#    </div>
#    <div class="grid product-grid">
#     <aside class="side-filter">
#      <div id="js-vue-cars-scope">
#       <filter-attributes :schemas='[{"attr_id": 1000000, "attr_name": "Inspection", "attr_parent_id": null, "attr_parent_name": null, "attr_type": "str", "filter_name": "filter_inspection", "filter_placeholder": null, "filter_type": "term", "for_header": true, "is_multiple": false, "label": "Inspection", "parent_slug": null, "popular_values": [], "possible_values": [{"count": 166, "value": "Inspected"}, {"count": 9592, "value": "Not inspected"}], "slug": "filter_inspection", "value": null, "visual_type": "select"}, {"attr_id": 1, "attr_name": "Make", "attr_parent_id": null, "attr_parent_name": null, "attr_type": "str", "filter_name": "filter_attr_1_make", "filter_placeholder": null, "filter_type": "term", "for_header": true, "is_multiple": false, "label": "Make", "parent_slug": null, "popular_values": [{"count": 259, "value": "Ford"}, {"count": 847, "value": "Honda"}, {"count": 941, "value": "Lexus"}, {"count": 1774, "value": "Mercedes-Benz"}, {"count": 3988, "value": "Toyota"}], "possible_values": [{"count": 84, "value": "Acura"}, {"count": 2, "value": "Alfa Romeo"}, {"count": 0, "value": "Aston Martin"}, {"count": 31, "value": "Audi"}, {"count": 0, "value": "BAW"}, {"count": 9, "value": "Bentley"}, {"count": 231, "value": "BMW"}, {"count": 2, "value": "Brabus"}, {"count": 4, "value": "Buick"}, {"count": 21, "value": "Cadillac"}, {"count": 1, "value": "Changan"}, {"count": 0, "value": "Chery"}, {"count": 52, "value": "Chevrolet"}, {"count": 24, "value": "Chrysler"}, {"count": 1, "value": "Citroen"}, {"count": 0, "value": "Daewoo"}, {"count": 0, "value": "Daihatsu"}, {"count": 0, "value": "Datsun"}, {"count": 39, "value": "Dodge"}, {"count": 0, "value": "Dongfeng"}, {"count": 3, "value": "Ferrari"}, {"count": 2, "value": "Fiat"}, {"count": 259, "value": "Ford"}, {"count": 0, "value": "Foton"}, {"count": 2, "value": "GAC"}, {"count": 0, "value": "Geely"}, {"count": 11, "value": "GMC"}, {"count": 0, "value": "Great Wall"}, {"count": 847, "value": "Honda"}, {"count": 0, "value": "Hummer"}, {"count": 244, "value": "Hyundai"}, {"count": 23, "value": "Infiniti"}, {"count": 0, "value": "Isuzu"}, {"count": 5, "value": "IVM"}, {"count": 2, "value": "JAC"}, {"count": 26, "value": "Jaguar"}, {"count": 31, "value": "Jeep"}, {"count": 0, "value": "Joylong"}, {"count": 132, "value": "Kia"}, {"count": 11, "value": "Lamborghini"}, {"count": 248, "value": "Land Rover"}, {"count": 941, "value": "Lexus"}, {"count": 9, "value": "Lincoln"}, {"count": 0, "value": "Mahindra"}, {"count": 4, "value": "Maserati"}, {"count": 63, "value": "Mazda"}, {"count": 1774, "value": "Mercedes-Benz"}, {"count": 1, "value": "Mercury"}, {"count": 2, "value": "MG"}, {"count": 34, "value": "Mini"}, {"count": 16, "value": "Mitsubishi"}, {"count": 0, "value": "Morris"}, {"count": 103, "value": "Nissan"}, {"count": 0, "value": "Nord"}, {"count": 8, "value": "Opel"}, {"count": 230, "value": "Peugeot"}, {"count": 0, "value": "Polaris"}, {"count": 82, "value": "Pontiac"}, {"count": 11, "value": "Porsche"}, {"count": 1, "value": "Renault"}, {"count": 12, "value": "Rolls-Royce"}, {"count": 5, "value": "Rover"}, {"count": 1, "value": "Saab"}, {"count": 3, "value": "Saturn"}, {"count": 7, "value": "Scion"}, {"count": 0, "value": "Seat"}, {"count": 2, "value": "Skoda"}, {"count": 0, "value": "Smart"}, {"count": 0, "value": "SsangYong"}, {"count": 6, "value": "Subaru"}, {"count": 4, "value": "Suzuki"}, {"count": 0, "value": "Tata"}, {"count": 3988, "value": "Toyota"}, {"count": 89, "value": "Volkswagen"}, {"count": 11, "value": "Volvo"}, {"count": 4, "value": "Other Make"}], "slug": "filter_attr_1_make", "value": null, "visual_type": "select"}, {"attr_id": 119, "attr_name": "Year of manufacture", "attr_parent_id": null, "attr_parent_name": null, "attr_type": "int", "filter_data": {"max": {"default": 2022.0, "fieldname": "filter_attr_119_year_of_manufacture__max", "value": ""}, "min": {"default": 1965.0, "fieldname": "filter_attr_119_year_of_manufacture__min", "value": ""}}, "filte ...
#       </filter-attributes>
#      </div>
#      <noscript>
#       <div class="b-filter-attributes">
#       </div>
#      </noscript>
#     </aside>
#     <main>
#      <h1>
#       9758 cars match your search
#      </h1>
#      <section class="budget-filter">
#       <div class="section-container">
#        <div class="price-filter flex justify-center">
#         <label class="price-filter__item">
#          <a href="/listing?price_max=2000000">
#           <div>
#            <span>
#            </span>
#            &lt; 2 M
#           </div>
#          </a>
#         </label>
#         <label class="price-filter__item">
#          <a href="/listing?price_max=3000000&amp;price_min=2000000">
#           <div>
#            <span>
#            </span>
#            2-3 M
#           </div>
#          </a>
#         </label>
#         <label class="price-filter__item">
#          <a href="/listing?price_max=4000000&amp;price_min=3000000">
#           <div>
#            <span>
#            </span>
#            3-4 M
#           </div>
#          </a>
#         </label>
#         <label class="price-filter__item">
#          <a href="/listing?price_min=4000000">
#           <div>
#            <span>
#            </span>
#            &gt; 4 M
#           </div>
#          </a>
#         </label>
#        </div>
#        <div class="brand-filter flex wrap justify-center">
#         <label class="brand-filter__item">
#          <a href="/listing/toyota">
#           <div class="brand-filter__detail">
#            <div class="brand-filter__image">
#             <img alt="Toyota" src="https://assets.jiji.ng/art/attributes/top-selection/cars2x-tinifield/toyota2x.png"/>
#            </div>
#            <span>
#             Toyota
#            </span>
#           </div>
#          </a>
#         </label>
#         <label class="brand-filter__item">
#          <a href="/listing/lexus">
#           <div class="brand-filter__detail">
#            <div class="brand-filter__image">
#             <img alt="Lexus" src="https://assets.jiji.ng/art/attributes/top-selection/cars2x-tinifield/lexus2x.png"/>
#            </div>
#            <span>
#             Lexus
#            </span>
#           </div>
#          </a>
#         </label>
#         <label class="brand-filter__item">
#          <a href="/listing/honda">
#           <div class="brand-filter__detail">
#            <div class="brand-filter__image">
#             <img alt="Honda" src="https://assets.jiji.ng/art/attributes/top-selection/cars2x-tinifield/honda2x.png"/>
#            </div>
#            <span>
#             Honda
#            </span>
#           </div>
#          </a>
#         </label>
#         <label class="brand-filter__item">
#          <a href="/listing/mercedes-benz">
#           <div class="brand-filter__detail">
#            <div class="brand-filter__image">
#             <img alt="Mercedes-Benz" src="https://assets.jiji.ng/art/attributes/top-selection/cars2x-tinifield/merdeces2x.png"/>
#            </div>
#            <span>
#             Mercedes-Benz
#            </span>
#           </div>
#          </a>
#         </label>
#         <label class="brand-filter__item">
#          <a href="/listing/nissan">
#           <div class="brand-filter__detail">
#            <div class="brand-filter__image">
#             <img alt="Nissan" src="https://assets.jiji.ng/art/attributes/top-selection/cars2x-tinifield/nissan2x.png"/>
#            </div>
#            <span>
#             Nissan
#            </span>
#           </div>
#          </a>
#         </label>
#         <label class="brand-filter__item">
#          <a href="/listing/ford">
#           <div class="brand-filter__detail">
#            <div class="brand-filter__image">
#             <img alt="Ford" src="https://assets.jiji.ng/art/attributes/top-selection/cars2x-tinifield/ford2x.png"/>
#            </div>
#            <span>
#             Ford
#            </span>
#           </div>
#          </a>
#         </label>
#         <label class="brand-filter__item">
#          <a href="/listing/land_rover">
#           <div class="brand-filter__detail">
#            <div class="brand-filter__image">
#             <img alt="Land Rover" src="https://assets.jiji.ng/art/attributes/top-selection/cars2x-tinifield/land-rover2x.png"/>
#            </div>
#            <span>
#             Land Rover
#            </span>
#           </div>
#          </a>
#         </label>
#         <label class="brand-filter__item">
#          <a href="/listing/acura">
#           <div class="brand-filter__detail">
#            <div class="brand-filter__image">
#             <img alt="Acura" src="https://assets.jiji.ng/art/attributes/top-selection/cars2x-tinifield/acura.png"/>
#            </div>
#            <span>
#             Acura
#            </span>
#           </div>
#          </a>
#         </label>
#        </div>
#       </div>
#      </section>
#      <section class="cars-grid grid">
#       <a class="car-feature" href="/n1BsvbwaFy8Lsy7L0ZXvHNRg">
#        <div class="car-feature__image">
#         <img alt="Toyota Corolla 2012 Silver for sale" src="https://pictures-nigeria.jijistatic.com/81111594_MTgwLTEzNS0yZDhhYzU0MmY3.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Toyota Corolla 2012 Silver
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 3,400,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Nigerian Used
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/hLVjxh2EyIY5efuFSJtO3ycr">
#        <div class="car-feature__image">
#         <img alt="Toyota Camry 2009 Gray for sale" src="https://pictures-nigeria.jijistatic.com/78882849_MTgwLTEzNS1hOWYzZTFiODFhLTE.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Toyota Camry 2009 Gray
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 2,500,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Nigerian Used
#          </span>
#          <span>
#           454203 km
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/Tn86e7flIOhbSmSnwETjRSf">
#        <div class="car-feature__image">
#         <img alt="Jeep Wrangler 2013 Unlimited Sport Blue for sale" src="https://pictures-nigeria.jijistatic.com/76459221_MTgwLTEzNS1hNjA3MjYxYjli.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Jeep Wrangler 2013 Unlimited Sport Blue
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 12,000,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#          <span>
#           53200 km
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/rN6cJS48CiWuZAWdErRXQcQi">
#        <div class="car-feature__image">
#         <img alt="BMW Z4 2010 sDrive28i White for sale" src="https://pictures-nigeria.jijistatic.com/76025990_MTgwLTI0MC1mMjc2NmEzYTZj.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          BMW Z4 2010 sDrive28i White
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 5,300,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#          <span>
#           98157 km
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/nkSHd7MCXkWh2WmI0xdJCpZy">
#        <div class="car-feature__image">
#         <img alt="Peugeot 207 2008 Gray for sale" src="https://pictures-nigeria.jijistatic.com/76502632_MTgwLTEzNS01NDUzYzI1Nzgz.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Peugeot 207 2008 Gray
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 1,800,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/yElN1JVOJgdE7U23mQHqfkZX">
#        <div class="car-feature__image">
#         <img alt="New Land Rover Range Rover 2020 Blue for sale" src="https://pictures-nigeria.jijistatic.com/75961125_MTgwLTEzNS03Y2RiMzNhY2Vl.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          New Land Rover Range Rover 2020 Blue
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 75,000,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Brand New
#          </span>
#          <span>
#           794 km
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/hVRuNvfDXSp2W70joW6d4n3">
#        <div class="car-feature__image">
#         <img alt="Peugeot 307 2007 Silver for sale" src="https://pictures-nigeria.jijistatic.com/74943669_MTgwLTI0MC0yMzI5NzJkY2QzLTE.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Peugeot 307 2007 Silver
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 2,000,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#          <span>
#           120000 km
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/BG3wviNulfSa3bYOJyGSPz1S">
#        <div class="car-feature__image">
#         <img alt="Mercedes-Benz E350 2012 White for sale" src="https://pictures-nigeria.jijistatic.com/67232434_MTgwLTEzNS0yMTg5ODY5MDVj.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Mercedes-Benz E350 2012 White
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 4,700,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Nigerian Used
#          </span>
#          <span>
#           85000 km
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/8x9SiEXagKKIX8U7YZ8mAsiC">
#        <div class="car-feature__image">
#         <img alt="Mazda 3 2014 White for sale" src="https://pictures-nigeria.jijistatic.com/80242277_MTgwLTI0MC1iODgzMzU3OTBmLTE.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Mazda 3 2014 White
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 5,000,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/q3QJTTjN8P7xvk1ISyU6OCT2">
#        <div class="car-feature__image">
#         <img alt="Infiniti FX35 2005 Base 4x2 (3.5L 6cyl 5A) Blue for sale" src="https://pictures-nigeria.jijistatic.com/79132146_MTgwLTEzNS02NGRhMTY4NjM2.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Infiniti FX35 2005 Base 4x2 (3.5L 6cyl 5A) Blue
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 1,800,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Nigerian Used
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/wpuxfN3I0jHO5pGhJUFx0YKi">
#        <div class="car-feature__image">
#         <img alt="Rover Land 2020 Black for sale" src="https://pictures-nigeria.jijistatic.com/77343198_MTgwLTEzNS04ODdiY2EzOWFj.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Rover Land 2020 Black
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 55,000,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/nh6YY0RekBXe9WD5ZysfJAko">
#        <div class="car-feature__image">
#         <img alt="Toyota Corolla Verso 2008 Black for sale" src="https://pictures-nigeria.jijistatic.com/76502183_MTgwLTEzNS1jZTgzNjVlODMw.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Toyota Corolla Verso 2008 Black
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 2,700,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/a0B5qpp47m8S0NKADgrEvghT">
#        <div class="car-feature__image">
#         <img alt="Mercedes-Benz CLA-Class 2016 Base CLA 250 FWD Gray for sale" src="https://pictures-nigeria.jijistatic.com/80221384_MTgwLTEzNS1hYjczN2Q0YzRj.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Mercedes-Benz CLA-Class 2016 Base CLA 250 FWD Gray
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 9,800,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/myM3KgHIJXL7M6GP6iU2fyKU">
#        <div class="car-feature__image">
#         <img alt="Toyota RAV4 2008 Gray for sale" src="https://pictures-nigeria.jijistatic.com/78184848_MTgwLTEzNS0yZjE3MTcxNmJk.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Toyota RAV4 2008 Gray
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 3,890,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Foreign Used
#          </span>
#          <span>
#           172000 km
#          </span>
#         </div>
#        </div>
#       </a>
#       <a class="car-feature" href="/3fGcpC7UrtZHw2Q3h8wQNtaP">
#        <div class="car-feature__image">
#         <img alt="Mercedes-Benz C300 2009 Silver for sale" src="https://pictures-nigeria.jijistatic.com/79751161_MTgwLTEzNS00ODRmZWFhOThi.jpg"/>
#        </div>
#        <div class="car-feature__details">
#         <p class="car-feature__name">
#          Mercedes-Benz C300 2009 Silver
#         </p>
#         <p class="car-feature__amount">
#          â‚¦ 3,500,000
#         </p>
#         <div class="car-feature__others">
#          <span>
#           Nigerian Used
#          </span>
#         </div>
#        </div>
#       </a>
#      </section>
#      <div class="h-mb-40 h-flex-center">
#       <div class="h-mt-20 h-text-center h-flex-center">
#        <ul class="b-pagination">
#         <li class="b-pagination__item disabled">
#          <a>
#           Â«
#          </a>
#         </li>
#         <li class="b-pagination__item b-pagination__item--active">
#          <a class="js-handle-link-events js-handle-click-ctr">
#           1
#          </a>
#         </li>
#         <li class="b-pagination__item">
#          <a class="js-handle-link-events js-handle-click-ctr" href="/listing/page2?listing_id=uEcblMCROQ2zlbzq&amp;region_subdomain=abuja">
#           2
#          </a>
#         </li>
#         <li class="b-pagination__item">
#          <a class="js-handle-link-events js-handle-click-ctr" href="/listing/page3?listing_id=uEcblMCROQ2zlbzq&amp;region_subdomain=abuja">
#           3
#          </a>
#         </li>
#         <li class="b-pagination__item">
#          <a class="js-handle-link-events js-handle-click-ctr" href="/listing/page4?listing_id=uEcblMCROQ2zlbzq&amp;region_subdomain=abuja">
#           4
#          </a>
#         </li>
#         <li class="b-pagination__item">
#          <a class="js-handle-link-events js-handle-click-ctr" href="/listing/page5?listing_id=uEcblMCROQ2zlbzq&amp;region_subdomain=abuja">
#           5
#          </a>
#         </li>
#         <li class="b-pagination__item">
#          <a class="js-handle-link-events js-handle-click-ctr" href="/listing/page6?listing_id=uEcblMCROQ2zlbzq&amp;region_subdomain=abuja">
#           6
#          </a>
#         </li>
#         <li class="b-pagination__item">
#          <a class="js-handle-link-events js-handle-click-ctr" href="/listing/page7?listing_id=uEcblMCROQ2zlbzq&amp;region_subdomain=abuja">
#           7
#          </a>
#         </li>
#         <li class="b-pagination__item disabled">
#          <a class="js-handle-link-events js-handle-click-ctr">
#           ...
#          </a>
#         </li>
#         <li class="b-pagination__item">
#          <a class="js-handle-link-events js-handle-click-ctr" href="/listing/page500?listing_id=uEcblMCROQ2zlbzq&amp;region_subdomain=abuja">
#           500
#          </a>
#         </li>
#         <li class="b-pagination__item">
#          <a class="js-handle-click-ctr" href="/listing/page2?listing_id=uEcblMCROQ2zlbzq&amp;region_subdomain=abuja">
#           Â»
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </main>
#    </div>
#   </section>
#   <form class="mobile-car-search" style="display: none;">
#    <label name="">
#     <button>
#      <img alt="Search" src="https://assets.jiji.ng/static/cars45_files/back.svg"/>
#     </button>
#     <input id="" placeholder="Find car by model, year..." type="search"/>
#    </label>
#    <div class="filter-dropdown" style="display: none;">
#    </div>
#   </form>
#   <form class="mobile-car-search" id="locationsMobile" style="display: none;">
#    <label name="">
#     <button id="closeMobileBtn">
#      <img alt="Back" src="https://assets.jiji.ng/static/cars45_files/back.svg"/>
#     </button>
#     <input id="" placeholder="Find city ..." type="search"/>
#    </label>
#    <div class="location-dropdown">
#     <ul class="location-dropdown__list">
#     </ul>
#    </div>
#   </form>
#   <footer>
#    <div class="main-container">
#     <p>
#      Cars45 â€¢ powered by Jiji
#     </p>
#    </div>
#   </footer>
#   <script>
#    if (window.jiji) {
#             if (window.jiji.flagFeatures) {
#                 window.jiji.flagFeatures.web_disable_all_analytics = true;
#                 window.jiji.flagFeatures.web_force_enable_cars45_tag_manager = true;
#             } else {
#                 window.jiji.flagFeatures = {
#                     web_disable_all_analytics: true,
#                     web_force_enable_cars45_tag_manager: true,
#                 }
#             }
#         } else {
#             window.jiji = {
#                 flagFeatures: {
#                     web_disable_all_analytics: true,
#                     web_force_enable_cars45_tag_manager: true,
#                 }
#             }
#         }
#   </script>
#   <script nonce="FHDnU4adUXYeacirGGkVHl6K1bOozYMZ">
#    !function(e){"use strict";var n=function(n,t,o){var i,r=e.document,d=r.createElement("link");if(t)i=t;else{var a=(r.body||r.getElementsByTagName("head")[0]).childNodes;i=a[a.length-1]}var l=r.styleSheets;d.rel="stylesheet",d.href=n,d.media="only x",function e(n){if(r.body)return n();setTimeout(function(){e(n)})}(function(){i.parentNode.insertBefore(d,t?i:i.nextSibling)});var f=function(e){for(var n=d.href,t=l.length;t--;)if(l[t].href===n)return e();setTimeout(function(){f(e)})};function s(){d.addEventListener&&d.removeEventListener("load",s),d.media=o||"all"}return d.addEventListener&&d.addEventListener("load",s),d.onloadcssdefined=f,f(s),d};"undefined"!=typeof exports?exports.loadCSS=n:e.loadCSS=n}("undefined"!=typeof global?global:this);
#   </script>
#   <script nonce="FHDnU4adUXYeacirGGkVHl6K1bOozYMZ">
#    window.path_for_static = "https://assets.jiji.ng/static/";
#         window.app_cookie_domain = ".jiji.ng";
#         window.app_config = {"adsense_data": {"targeting_price_list": [[0, 500000], [500000, 1000000], [1000000, 2000000], [2000000, 3000000], [3000000, 4000000], [4000000, 5000000], [5000000, 10000000], [10000000, 100000000000]]}, "app": {"android": {"id": "ng.jiji.app", "url": "https://play.google.com/store/apps/details?id=ng.jiji.app"}, "ios": {"id": "966165025", "url": "https://itunes.apple.com/us/app/jiji.ng/id966165025"}}, "auction": {"ws_server_url": "wss://ws.jiji.ng/ws-auction"}, "country_name": "Nigeria", "currency": {"cents_in_unit": 100, "code": "NGN", "name": "Naira", "price_accuracy": 1000, "price_format": "{symbol} {price}", "symbol": "\u20a6"}, "debug": false, "device": {"desktop": true, "is_web_view": false, "mobile": false, "tablet": false}, "has_app": true, "is_bot": false, "messenger": {"audio_max_size": 5242880, "ws_server_url": "wss://ws.jiji.ng/ws"}, "premium_services_enabled": true, "social_data": {"facebook_auth": {"params": ["url", "fb_share"], "url": "https://jiji.ng/social-auth.html"}, "facebook_support_contact_id": "463583521052737", "google_auth": {"params": ["url"], "url": "https://jiji.ng/google-auth.html"}, "intercom_support_contact_id": "ugmhsbgy", "one_tap_client_id": "882600435014-q07n5pempn80t3hhoqc6cqn5vchp0otq.apps.googleusercontent.com", "sharing": {"facebook": "https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fjiji.ng%3Futm_campaign%3DfacebookButton%26utm_medium%3Dsite-share-button%26utm_source%3Dfacebook%26p%3D27\u0026t=Join+Jiji", "mail": "mailto:?body=https%3A%2F%2Fjiji.ng%3Futm_campaign%3DemailButton%26utm_medium%3Dsite-share-button%26utm_source%3Demail%26p%3D27\u0026subject=Join+Jiji", "twitter": "http://twitter.com/share?url=https%3A%2F%2Fjiji.ng\u0026text=Join+Jiji", "whats_app": "whatsapp://send?text=https%3A%2F%2Fjiji.ng"}, "whats_app_available": false, "whats_app_support_contact_link": "https://wa.me/2347059978547"}, "tag_manager": {"AW_id": "AW-961380439", "UA_id": "UA-137059257-1", "cars_id": "G-3Z1QJFFS8L"}, "tz": "Africa/Lagos", "urls": {"media_recorder_polyfill": "https://assets.jiji.ng/static/bundles/js/media-recorder-polyfill-js.b776368243ae90dc23ea.min.js", "svg_sprite_url": "https://assets.jiji.ng/static/bundles/sprites/svg/sprite-svg-6c37d002.svg"}, "validation": {"password": {"min_length": 6}, "phone": {"country_code": "234", "operator_length": 2, "operators": ["70", "80", "81", "90", "91"], "phone_len": 10, "prefix": "0", "regexp": "^(?:2340|234|0|)((70|80|81|90|91)\\d{8})$", "search_regexp": "(?\u003c!\\d)((?:2340|234|0|447)?\\d{8,10})(?!\\d)", "search_regexp_advanced": "(?\u003c!\\d)[_\\W]{,5}(((?:2[_\\W]{,5}3[_\\W]{,5}4[_\\W]{,5}0|2[_\\W]{,5}3[_\\W]{,5}4|0)?[_\\W]{,5}(7[_\\W]{,5}0|8[_\\W]{,5}0|8[_\\W]{,5}1|9[_\\W]{,5}0|9[_\\W]{,5}1)[_\\W]{,5}(\\d[_\\W]{,5}){5,7}\\d)|(4[_\\W]{,5}4[_\\W]{,5}7[_\\W]{,5}(\\d[_\\W]{,5}){8}\\d))(?!\\d)"}}};
#         window.user = {"auth_url": "https://jiji.ng/login.html", "created_at": null, "fb_data": {}, "googletag_seller_keyword": null, "id": null, "statuses": {"active": false, "blocked": false, "duplicated": false, "hacked": false, "spammer": false}};
#         window.fb_pixel_ids = ["2360032340708416", "2150104691766621"];
#         window.twitter_business_id = "o4kdg";
#         window.gtag_aw_id = "AW-961380439";
#         window.is_adsense_available = true;
#         window.is_spa = false;
#         window.web_id = "1636550665##3b75d68bdcf3abf18fd82fb417a38ecd879536e2"
#         window.start_spa_data = {"auction_categories": [29], "bidding": {"max_bid_amount": 41057000, "min_bid_amount": 42000, "steps": {"rules": [{"max": 50000, "step": 500}, {"max": 100000, "step": 1000}, {"max": 250000, "step": 2000}, {"max": 1000000, "step": 5000}, {"max": 2500000, "step": 10000}, {"max": 10000000, "step": 25000}, {"max": null, "step": 50000}], "type": "value"}, "values": {"dest": "price", "rules": [{"max": 0.25, "vals": [0.3, 0.4]}, {"max": 0.4, "vals": [0.45, 0.55]}, {"max": 0.55, "vals": [0.6, 0.65]}, {"max": 0.7, "vals": [0.75, 0.8]}, {"max": 0.85, "vals": [0.9, 0.95]}], "type": "percent"}}, "categories": [{"childes": [{"childes": [], "id": 29, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/vehicles/cars.png", "name": "Cars", "parent_id": 6, "position": 101, "slug": "cars"}, {"childes": [], "id": 382, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/vehicles/buses.png", "name": "Buses \u0026 Microbuses", "parent_id": 6, "position": 102, "slug": "buses"}, {"childes": [], "id": 274, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/vehicles/heavy-equipment.png", "name": "Heavy Equipment", "parent_id": 6, "position": 103, "slug": "heavy-equipments-machinery"}, {"childes": [], "id": 30, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/vehicles/moto.png", "name": "Motorcycles \u0026 Scooters", "parent_id": 6, "position": 104, "slug": "motorcycles-and-scooters"}, {"childes": [], "id": 31, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/vehicles/trucks-and-trailers.png", "name": "Trucks \u0026 Trailers", "parent_id": 6, "position": 105, "slug": "trucks-commercial-agricultiral"}, {"childes": [], "id": 12, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/vehicles/vehicle-parts-and-accessories.png", "name": "Vehicle Parts \u0026 Accessories", "parent_id": 6, "position": 106, "slug": "car-parts-and-accessories"}, {"childes": [], "id": 275, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/vehicles/watercrafts.png", "name": "Watercraft \u0026 Boats", "parent_id": 6, "position": 108, "slug": "watercrafts-vehicle"}], "id": 6, "image": "vehicles", "image_v2": "https://assets.jiji.ng/art/attributes/categories/vehicles.png", "name": "Vehicles", "parent_id": null, "position": 100, "slug": "vehicles"}, {"childes": [{"childes": [], "id": 42, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/real-estate/houses-and-apartments-for-rent.png", "name": "Houses \u0026 Apartments For Rent", "parent_id": 9, "position": 204, "slug": "houses-apartments-for-rent"}, {"childes": [], "id": 43, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/real-estate/houses-and-apartments-for-sale.png", "name": "Houses \u0026 Apartments For Sale", "parent_id": 9, "position": 205, "slug": "houses-apartments-for-sale"}, {"childes": [], "id": 283, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/real-estate/land-for-rent.png", "name": "Land \u0026 Plots for Rent", "parent_id": 9, "position": 206, "slug": "land-and-plots-for-rent"}, {"childes": [], "id": 44, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/real-estate/land-and-plots-for-sale.png", "name": "Land \u0026 Plots For Sale", "parent_id": 9, "position": 207, "slug": "land-and-plots-for-sale"}, {"childes": [], "id": 278, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/real-estate/commercial-property-for-rent.png", "name": "Commercial Property For Rent", "parent_id": 9, "position": 210, "slug": "commercial-property-for-rent"}, {"childes": [], "id": 46, "image": null, "image_v2": "https://assets.jiji.ng/art/attributes/categories/real-estate/commercial-property-for-sale.png", "name": "Commercial Property For Sale", "parent_id": 9, "position": 211, "slug": "commercial-pr ...
#             window.footer = {"aside_text": "", "copyright": "\u00a9 2021 Jiji.ng", "links": [{"group": "about_us", "links": [{"text": "About Jiji", "url": "/about.html"}, {"text": "We are hiring!", "url": "/hiring.html"}, {"text": "Terms \u0026 Conditions", "url": "/rules.html"}, {"text": "Privacy Policy", "url": "/privacy.html"}, {"text": "Billing Policy", "url": "/billing-policy.html"}, {"text": "Cookie policy", "url": "/jiji-pages/cookie-policy"}], "title": "About us"}, {"group": "support", "links": [{"text": "support@jiji.ng", "url": "mailto:support@jiji.ng"}, {"text": "Safety Tips", "url": "/safety-tips.html"}, {"text": "Contact Us", "url": "/contacts.html"}, {"text": "FAQ", "url": "/faq"}], "title": "Support"}, {"group": "apps_data", "links": [{"image_url": "https://assets.jiji.ng/static/img/single-images/ios.svg", "text": "", "url": "https://itunes.apple.com/us/app/jiji.ng/id966165025"}, {"image_url": "https://assets.jiji.ng/static/img/single-images/android.svg", "text": "", "url": "https://play.google.com/store/apps/details?id=ng.jiji.app"}], "title": "Our apps"}, {"group": "payment", "title": "Payment method"}, {"group": "resources", "links": [{"exist_in_spa": false, "text": "Our blog", "url": "https://jiji-blog.com"}, {"exist_in_spa": false, "text": "Jiji on FB", "url": "https://www.facebook.com/Jiji.Nigeria"}, {"exist_in_spa": false, "text": "Our Instagram", "url": "https://www.instagram.com/jijinigeria/"}, {"exist_in_spa": false, "text": "Our Youtube", "url": "https://www.youtube.com/channel/UCvAyphNspDQMFnp7g57jH-g"}, {"exist_in_spa": false, "text": "Our Twitter", "url": "https://twitter.com/jijinigeria"}], "title": "Our resources"}, {"group": "hot_links", "links": [{"text": "Brand", "url": "/brand"}, {"text": "Jiji Sellers", "url": "/company"}, {"text": "Regions", "url": "/regions"}, {"text": "Jiji Africa", "url": "https://jiji.africa"}], "title": "Hot links"}]}
#             window.header = {"links": [{"show_on_tablet": true, "text": "Sign in", "url": "/login.html"}, {"show_on_tablet": true, "text": "Registration", "url": "/registration.html"}]}
#             window.header_counts = {"messages": 0, "notifications": 0}
#   </script>
#   <script nonce="FHDnU4adUXYeacirGGkVHl6K1bOozYMZ">
#    window.googleDataLayer = [];
#         window.facebookDataLayer = [];
#         window.twitterDataLayer = [];
#         window.tagDataLayer = [];
#         window.flagInteractionDataLayer = [];
#         if(!window.jiji) { window.jiji = {} }
#         if(!window.jiji.components) { window.jiji.components = {} }
#         if(!window.jiji.components.TagEvent) { window.jiji.components.TagEvent = {} }
#         window.jiji.components.TagEvent.send = function(event, param_1, param_2) {
#             if (window.jiji.AnalyticsLegacyInstance) {
#                 window.jiji.AnalyticsLegacyInstance.sendTagEvent({
#                     event,
#                     params: {
#                         param_1,
#                         param_2,
#                     }
#                 })
#             } else {
#                 window.tagDataLayer.push({
#                     event,
#                     params: {
#                         param_1,
#                         param_2,
#                     }
#                 })
#             }
#         };
#         window.errorsLoggerDataLayer = [];
#         window.errorsLoggerEventListener  = function(e) {
#             if (e) {
#                 window.errorsLoggerDataLayer.push(e);
#             }
#         }
#         window.addEventListener(`error`, window.errorsLoggerEventListener);
#   </script>
#   <script nonce="FHDnU4adUXYeacirGGkVHl6K1bOozYMZ" src="https://assets.jiji.ng/static/bundles/js/vue-cars-js.00a4b26d13358d289af5.min.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# # Results

# %%
#scrape the listings

listings = soup.find_all("a", class_ = "car-feature")

# %%
# The first listing on the web page
listings[0].get_text()
# Out:
# '\n\n\n\n\nToyota Corolla 2012 Silver\nâ‚¦ 3,400,000\n\nNigerian Used\n\n\n'

# %%
#Total listings on each page
len(listings)
# Out:
# 15

# %% [markdown]
# ## The Data I need to scrape

# %% [markdown]
# 1. Car Make
# 2. Year of Manufacture and colour
# 3. Price
# 4. Condition_mileage
# 5. Milage(KM)

# %% [markdown]
# #### Car Make

# %%
listings[0].find("p", class_ = "car-feature__name").get_text()
# Out:
# 'Toyota Corolla 2012 Silver'

# %% [markdown]
# #### Price

# %%
listings[0].find("p", class_ = "car-feature__amount").get_text().strip()
# Out:
# 'â‚¦ 3,400,000'

# %% [markdown]
# #### Condition_mileage

# %%
listings[0].find("div", class_ = "car-feature__others").get_text().strip()
# Out:
# 'Nigerian Used'

# %% [markdown]
# ## Use a For Loop to put everything together

# %%
#I'll create an empty lists for the data

car_make = []
price = []
condition_mileage = []

for i in listings:
    
    #car_make
    try:
        car_make.append(i.find("p", class_ = "car-feature__name").get_text())
    except:
        car_make.append("missing")
        
    #price
    try:
        price.append(i.find("p", class_ = "car-feature__amount").get_text().strip())
    except:
        price.append("missing")
        
    #condition and mileage
    try:
        condition_mileage.append(i.find("div", class_ = "car-feature__others").get_text().strip())
    except:
        condition_mileage.append("missing")

# %% [markdown]
# # Create a Pandas DataFrame to store the Data

# %%
car_info = pd.DataFrame({"Name": car_make, "Price": price, "Condition_mileage": condition_mileage})

# %%
car_info
# Out:
#                                                  Name           Price  \
# 0                          Toyota Corolla 2012 Silver   â‚¦ 3,400,000
# 1                              Toyota Camry 2009 Gray   â‚¦ 2,500,000
# 2             Jeep Wrangler 2013 Unlimited Sport Blue  â‚¦ 12,000,000
# 3                         BMW Z4 2010 sDrive28i White   â‚¦ 5,300,000
# 4                               Peugeot 207 2008 Gray   â‚¦ 1,800,000
# 5                New Land Rover Range Rover 2020 Blue  â‚¦ 75,000,000
# 6                             Peugeot 307 2007 Silver   â‚¦ 2,000,000
# 7                       Mercedes-Benz E350 2012 White   â‚¦ 4,700,000
# 8                                  Mazda 3 2014 White   â‚¦ 5,000,000
# 9     Infiniti FX35 2005 Base 4x2 (3.5L 6cyl 5A) Blue   â‚¦ 1,800,000
# 10                              Rover Land 2020 Black  â‚¦ 55,000,000
# 11                    Toyota Corolla Verso 2008 Black   â‚¦ 2,700,000
# 12  Mercedes-Benz CLA-Class 2016 Base CLA 250 FWD ...   â‚¦ 9,800,000
# 13                              Toyota RAV4 2008 Gray   â‚¦ 3,890,000
# 14                     Mercedes-Benz C300 2009 Silver   â‚¦ 3,500,000
#
#            Condition_mileage
# 0              Nigerian Used
# 1   Nigerian Used\n454203 km
# 2     Foreign Used\n53200 km
# 3     Foreign Used\n98157 km
# 4               Foreign Used
# 5          Brand New\n794 km
# 6    Foreign Used\n120000 km
# 7    Nigerian Used\n85000 km
# 8               Foreign Used
# 9              Nigerian Used
# 10              Foreign Used
# 11              Foreign Used
# 12              Foreign Used
# 13   Foreign Used\n172000 km
# 14             Nigerian Used

# %% [markdown]
# ## Data Cleaning

# %%
car_info["Price"] = car_info["Price"].apply(lambda x:x.strip("â‚¦"))

# %%
car_info
# Out:
#                                                  Name        Price  \
# 0                          Toyota Corolla 2012 Silver    3,400,000
# 1                              Toyota Camry 2009 Gray    2,500,000
# 2             Jeep Wrangler 2013 Unlimited Sport Blue   12,000,000
# 3                         BMW Z4 2010 sDrive28i White    5,300,000
# 4                               Peugeot 207 2008 Gray    1,800,000
# 5                New Land Rover Range Rover 2020 Blue   75,000,000
# 6                             Peugeot 307 2007 Silver    2,000,000
# 7                       Mercedes-Benz E350 2012 White    4,700,000
# 8                                  Mazda 3 2014 White    5,000,000
# 9     Infiniti FX35 2005 Base 4x2 (3.5L 6cyl 5A) Blue    1,800,000
# 10                              Rover Land 2020 Black   55,000,000
# 11                    Toyota Corolla Verso 2008 Black    2,700,000
# 12  Mercedes-Benz CLA-Class 2016 Base CLA 250 FWD ...    9,800,000
# 13                              Toyota RAV4 2008 Gray    3,890,000
# 14                     Mercedes-Benz C300 2009 Silver    3,500,000
#
#            Condition_mileage
# 0              Nigerian Used
# 1   Nigerian Used\n454203 km
# 2     Foreign Used\n53200 km
# 3     Foreign Used\n98157 km
# 4               Foreign Used
# 5          Brand New\n794 km
# 6    Foreign Used\n120000 km
# 7    Nigerian Used\n85000 km
# 8               Foreign Used
# 9              Nigerian Used
# 10              Foreign Used
# 11              Foreign Used
# 12              Foreign Used
# 13   Foreign Used\n172000 km
# 14             Nigerian Used

# %% [markdown]
# #### Save as CVS file

# %%
car_info.to_csv("car_info_singlepage.csv", index = False)

# %% [markdown]
# # Scraping Multiple Pages

# %%
# I'll create a for loop to loop through the pages
car_make = []
price = []
condition_mileage = []

for i in range(1,5):
    #assigning the website to a variable
    website = "https://cars45.com/listing/page" + str(i) + "?listing_id=0YcfpLlhS6mDDJRh&region_subdomain=abuja"
    
    #requests to website
    r = requests.get(website, headers = headers)
    
    #make soup object
    soup=BeautifulSoup(r.content,"lxml") 
    
    #scrape the listings from the pages
    listings = soup.find_all("a", class_ = "car-feature")
    
    for i in listings:
    
        #car_make
        try:
            car_make.append(i.find("p", class_ = "car-feature__name").get_text())
        except:
            car_make.append("missing")

        #price
        try:
            price.append(i.find("p", class_ = "car-feature__amount").get_text().strip())
        except:
            price.append("missing")

        #condition and mileage
        try:
            condition_mileage.append(i.find("div", class_ = "car-feature__others").get_text().strip())
        except:
            condition_mileage.append("missing")
        time.sleep(5)

# %%
car_info = pd.DataFrame({"Name": car_make, "Price": price, "Condition_mileage": condition_mileage})

# %%
car_info
# Out:
#                                              Name            Price  \
# 0                   Mercedes-Benz C250 2015 Black    â‚¦ 7,800,000
# 1                      Toyota Corolla 2007 S Blue    â‚¦ 2,100,000
# 2                       Jeep Wrangler 2007 Silver    â‚¦ 5,000,000
# 3                            Ford Edge 2014 Beige    â‚¦ 2,500,000
# 4                          Toyota Camry 2013 Gray    â‚¦ 3,700,000
# 5                   Mercedes-Benz E350 2006 Beige    â‚¦ 3,200,000
# 6                           New JAC S2 2019 Black    â‚¦ 6,500,000
# 7                         Toyota Camry 2014 Green    â‚¦ 3,800,000
# 8                Honda Accord 2003 Automatic Gold    â‚¦ 1,900,000
# 9                          Toyota Camry 2017 Gray    â‚¦ 9,000,000
# 10                        Honda Accord 2014 White    â‚¦ 5,700,000
# 11                  Mercedes-Benz C300 2010 White    â‚¦ 5,000,000
# 12           Toyota Land Cruiser Prado 2008 Black    â‚¦ 7,500,000
# 13                          Ford Edge 2014 Silver    â‚¦ 3,850,000
# 14                         Toyota Venza 2009 Blue    â‚¦ 6,600,000
# 15                        Lexus IS 2012 350 Black    â‚¦ 4,500,000
# 16                         Cadillac CTS 2013 Blue    â‚¦ 8,200,000
# 17                      Ford Fusion 2013 SE Black    â‚¦ 5,500,000
# 18                     Hyundai Genesis 2013 Black    â‚¦ 6,200,000
# 19                       BMW 7 Series 2017 Silver   â‚¦ 30,000,000
# 20                 Toyota Hilux 2014 SR 4x4 Black   â‚¦ 20,000,000
# 21                 Mercedes-Benz C350 2008 Silver    â‚¦ 3,800,000
# 22                      Toyota Corolla 2015 White    â‚¦ 5,700,000
# 23         Chevrolet Corvette 2019 Stingray White   â‚¦ 48,000,000
# 24                           Acura Tl 2012 silver    â‚¦ 2,045,000
# 25                        Toyota Camry 2016 White    â‚¦ 6,700,000
# 26                            Lexus LS 2011 Black    â‚¦ 7,500,000
# 27  New Toyota Land Cruiser 2021 4.0 V6 GXR Brown   â‚¦ 30,000,000
# 28             Mercedes-Benz GLE-Class 2020 Black   â‚¦ 55,000,000
# 29                            BMW 535i 2014 Black    â‚¦ 7,500,000
# 30                    Toyota Highlander 2008 Gray    â‚¦ 4,162,500
# 31        New Rolls-Royce Cullinan 2021 Base Blue  â‚¦ 414,200,000
# 32           Toyota Land Cruiser Prado 2014 Black   â‚¦ 17,000,000
# 33                            Lexus LX 2017 White   â‚¦ 54,900,000
# 34                             BMW X3 2013 Silver    â‚¦ 8,500,000
# 35                        Lexus RX 2007 350 Black    â‚¦ 3,500,000
# 36                   Mercedes-Benz E350 2011 Gray    â‚¦ 7,200,000
# 37                        Peugeot 406 2005 Silver    â‚¦ 1,100,000
# 38  Mercedes-Benz M Class 2013 ML 350 4Matic Blue   â‚¦ 10,000,000
# 39                            Lexus RX 2000 Black    â‚¦ 1,350,000
# 40       New Toyota RAV4 2020 Adventure AWD Black   â‚¦ 23,000,000
# 41                   Mercedes-Benz E350 2014 Gray    â‚¦ 8,300,000
# 42                       Lexus LS 2010 460 L Gold    â‚¦ 5,550,000
# 43                     Toyota Corolla 2013 Silver    â‚¦ 3,400,000
# 44                         Toyota Camry 2010 Gray    â‚¦ 3,500,000
#
#            Condition_mileage
# 0               Foreign Used
# 1              Nigerian Used
# 2               Foreign Used
# 3   Nigerian Used\n100000 km
# 4              Nigerian Used
# 5               Foreign Used
# 6        Brand New\n16983 km
# 7    Nigerian Used\n60542 km
# 8    Foreign Used\n150000 km
# 9     Foreign Used\n56974 km
# 10              Foreign Used
# 11              Foreign Used
# 12             Nigerian Used
# 13  Nigerian Used\n115230 km
# 14              Foreign Used
# 15              Foreign Used
# 16    Foreign Used\n15300 km
# 17    Foreign Used\n51000 km
# 18    Foreign Used\n45123 km
# 19              Foreign Used
# 20              Foreign Used
# 21    Foreign Used\n95256 km
# 22    Foreign Used\n46670 km
# 23     Foreign Used\n2100 km
# 24                 105955 km
# 25    Foreign Used\n58431 km
# 26              Foreign Used
# 27        Brand New\n1214 km
# 28     Foreign Used\n5082 km
# 29   Nigerian Used\n43865 km
# 30                 124532 km
# 31          Brand New\n19 km
# 32   Nigerian Used\n87000 km
# 33              Foreign Used
# 34              Foreign Used
# 35  Nigerian Used\n135628 km
# 36              Foreign Used
# 37   Nigerian Used\n98000 km
# 38             Nigerian Used
# 39                 126385 km
# 40         Brand New\n200 km
# 41             Nigerian Used
# 42   Nigerian Used\n98988 km
# 43   Nigerian Used\n85421 km
# 44    Foreign Used\n90000 km

# %% [markdown]
# # Data Cleaning

# %%
car_info["Price"] = car_info["Price"].apply(lambda x:x.strip("â‚¦"))

# %%
car_info
# Out:
#                                              Name         Price  \
# 0                   Mercedes-Benz C250 2015 Black     7,800,000
# 1                      Toyota Corolla 2007 S Blue     2,100,000
# 2                       Jeep Wrangler 2007 Silver     5,000,000
# 3                            Ford Edge 2014 Beige     2,500,000
# 4                          Toyota Camry 2013 Gray     3,700,000
# 5                   Mercedes-Benz E350 2006 Beige     3,200,000
# 6                           New JAC S2 2019 Black     6,500,000
# 7                         Toyota Camry 2014 Green     3,800,000
# 8                Honda Accord 2003 Automatic Gold     1,900,000
# 9                          Toyota Camry 2017 Gray     9,000,000
# 10                        Honda Accord 2014 White     5,700,000
# 11                  Mercedes-Benz C300 2010 White     5,000,000
# 12           Toyota Land Cruiser Prado 2008 Black     7,500,000
# 13                          Ford Edge 2014 Silver     3,850,000
# 14                         Toyota Venza 2009 Blue     6,600,000
# 15                        Lexus IS 2012 350 Black     4,500,000
# 16                         Cadillac CTS 2013 Blue     8,200,000
# 17                      Ford Fusion 2013 SE Black     5,500,000
# 18                     Hyundai Genesis 2013 Black     6,200,000
# 19                       BMW 7 Series 2017 Silver    30,000,000
# 20                 Toyota Hilux 2014 SR 4x4 Black    20,000,000
# 21                 Mercedes-Benz C350 2008 Silver     3,800,000
# 22                      Toyota Corolla 2015 White     5,700,000
# 23         Chevrolet Corvette 2019 Stingray White    48,000,000
# 24                           Acura Tl 2012 silver     2,045,000
# 25                        Toyota Camry 2016 White     6,700,000
# 26                            Lexus LS 2011 Black     7,500,000
# 27  New Toyota Land Cruiser 2021 4.0 V6 GXR Brown    30,000,000
# 28             Mercedes-Benz GLE-Class 2020 Black    55,000,000
# 29                            BMW 535i 2014 Black     7,500,000
# 30                    Toyota Highlander 2008 Gray     4,162,500
# 31        New Rolls-Royce Cullinan 2021 Base Blue   414,200,000
# 32           Toyota Land Cruiser Prado 2014 Black    17,000,000
# 33                            Lexus LX 2017 White    54,900,000
# 34                             BMW X3 2013 Silver     8,500,000
# 35                        Lexus RX 2007 350 Black     3,500,000
# 36                   Mercedes-Benz E350 2011 Gray     7,200,000
# 37                        Peugeot 406 2005 Silver     1,100,000
# 38  Mercedes-Benz M Class 2013 ML 350 4Matic Blue    10,000,000
# 39                            Lexus RX 2000 Black     1,350,000
# 40       New Toyota RAV4 2020 Adventure AWD Black    23,000,000
# 41                   Mercedes-Benz E350 2014 Gray     8,300,000
# 42                       Lexus LS 2010 460 L Gold     5,550,000
# 43                     Toyota Corolla 2013 Silver     3,400,000
# 44                         Toyota Camry 2010 Gray     3,500,000
#
#            Condition_mileage
# 0               Foreign Used
# 1              Nigerian Used
# 2               Foreign Used
# 3   Nigerian Used\n100000 km
# 4              Nigerian Used
# 5               Foreign Used
# 6        Brand New\n16983 km
# 7    Nigerian Used\n60542 km
# 8    Foreign Used\n150000 km
# 9     Foreign Used\n56974 km
# 10              Foreign Used
# 11              Foreign Used
# 12             Nigerian Used
# 13  Nigerian Used\n115230 km
# 14              Foreign Used
# 15              Foreign Used
# 16    Foreign Used\n15300 km
# 17    Foreign Used\n51000 km
# 18    Foreign Used\n45123 km
# 19              Foreign Used
# 20              Foreign Used
# 21    Foreign Used\n95256 km
# 22    Foreign Used\n46670 km
# 23     Foreign Used\n2100 km
# 24                 105955 km
# 25    Foreign Used\n58431 km
# 26              Foreign Used
# 27        Brand New\n1214 km
# 28     Foreign Used\n5082 km
# 29   Nigerian Used\n43865 km
# 30                 124532 km
# 31          Brand New\n19 km
# 32   Nigerian Used\n87000 km
# 33              Foreign Used
# 34              Foreign Used
# 35  Nigerian Used\n135628 km
# 36              Foreign Used
# 37   Nigerian Used\n98000 km
# 38             Nigerian Used
# 39                 126385 km
# 40         Brand New\n200 km
# 41             Nigerian Used
# 42   Nigerian Used\n98988 km
# 43   Nigerian Used\n85421 km
# 44    Foreign Used\n90000 km

# %% [markdown]
# ### Save as csv file

# %%
car_info.to_csv("car_info_multiplepages.csv", index = False)
